# %% [markdown]
# # 🇧🇷 Auditoria do Mercado de Carbono: Volume vs Valor

# %% [markdown]
# ### Uma análise do Registro Verra (VCS) de 2015 a 2025

# %% [markdown]
# > **Resumo Executivo:** Esta auditoria desafia a visão tradicional do mercado de carbono. Enquanto a Ásia domina o volume físico (toneladas de CO2), o Brasil consolidou uma liderança oculta no **valor financeiro**, impulsionada pelo prêmio de preço dos projetos de conservação florestal (REDD+).
#
# ---

# %% [markdown]
# ## 1. Estratégia Técnica (ETL)
# Para realizar esta auditoria, construímos um pipeline que ingere os dados brutos de emissões (`Issuances`), normaliza caracteres especiais (correção de *Mojibake*) e aplica uma **Engine de Precificação** baseada na tipologia do projeto.

# %%
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
import matplotlib.ticker as mtick
import unicodedata
import warnings
import os

# Configurações Globais
warnings.filterwarnings("ignore")
sns.set_theme(style="whitegrid")
os.makedirs('./output', exist_ok=True)

# Ingestão de Dados
FILE_PATH = './data/raw_data_issuances.csv'
COLS_MAP = {
    'Name': 'project_name',
    'Country/Area': 'country',
    'Project Type': 'project_type',
    'Vintage End': 'vintage',
    'Quantity Issued': 'quantity'
}

df = pd.read_csv(FILE_PATH, usecols=COLS_MAP.keys(), encoding='latin1', low_memory=False)
df = df.rename(columns=COLS_MAP)

# Limpeza e Tipagem
if df['quantity'].dtype == 'O': 
    df['quantity'] = df['quantity'].astype(str).str.replace(',', '').astype(float)

df['vintage'] = pd.to_datetime(df['vintage'], errors='coerce').dt.year.fillna(0).astype(int)
df['country'] = df['country'].astype(str).str.strip().str.title()

print(f"Base carregada: {df.shape[0]:,} registros de emissão.")
# Out:
# ---------------------------------------------------------------------------
# FileNotFoundError                         Traceback (most recent call last)
# Cell In[2], line 24
#      15 FILE_PATH = './data/raw_data_issuances.csv'
#      16 COLS_MAP = {
#      17     'Name': 'project_name',
#      18     'Country/Area': 'country',
#    (...)     21     'Quantity Issued': 'quantity'
#      22 }
# ---> 24 df = pd.read_csv(FILE_PATH, usecols=COLS_MAP.keys(), encoding='latin1', low_memory=False)
#      25 df = df.rename(columns=COLS_MAP)
#      27 # Limpeza e Tipagem
#
# ...
